# %% [markdown]
# <div class="alert alert-success">
#   <b> ✔️Комментарий ревьюера ✔️</b>
#
# Привет! Меня зовут Михаил Майоров, я буду проверять твой проект. Предлагаю общаться на 'ты' :)
# Однако, если это неудобно - сообщи, и мы перейдем на 'Вы'. Моя главная цель —  поделиться с тобой своим опытом и помочь тебе стать аналитиком данных, а не только указать на совершенные тобой ошибки.
#
# Видно, что к проету приложен большой труд. Все ключевые этапы в работе выполнены, статистическое исследование проведено качественно. Так что в целом справиться с задачей тебе удалось.
#
# Есть несколько аспектов, которые **требуют** твоего **внимания**. Комментарии по ним помечены красным цветом и символами ❌. После их доработки проект будет принят, осталось совсем немного :)
#
#
# Давай работать над проектом в диалоге: если **ты что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Мне будет легче отследить изменения, если ты будешь использовать синюю форму, которую я прикреплю ниже. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
#
#
# Жду проект на повторное ревью. Успехов в изучении!
#
#
#
# </div>
# <div class="alert alert-block alert-danger"> <b>❌ Комментарий ревьюера ❌</b>
#     Так я выделяю моменты, которые требуют особого внимания. Нужно будет учесть их и внести корректировки в свою работу. </div>
# <div class="alert alert-block alert-warning"> <b>⚠️ Комментарий ревьюера ⚠️</b>
#     Желтым я отмечу рекомендации, которые, могут быть полезными при твоей работе. Они носят рекомендационный характер, но будет классно, если ты будешь учитывать их при работе.</div>
# <div class="alert alert-block alert-success"> <b>✔️ Комментарий ревьюера ✔️</b>
#     Так я выделяю удачные и элегантные решения, на которые можно опираться в будущих проектах.</div>
# <div class="alert alert-block alert-info">
#
# А в таком блоке ты можешь оставить комментарии для меня
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Привет, я рад знакомству. Меня зовут Андрей Карцев, но ты это и так, наверное, знаешь. Все свои изменения я буду описывать в синих блоках, я сам просил прошлого ревьюера об этом. Очень хорошо, что ты прислам мне код для окраски блоков в синий. Я рассчитывал, что все правки ревьюера останутся в проекте, но когда я перехожу в предыдущий сданный проект, моего диалога с проверяющим нет. Можно сделать как-то так, чтобы наш  с тобой диалог сохранился в будущем?
#     <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Привет, Андрей. Я рекомендую скачать проект из тетрадки, если есть такая проблема - file - download as - notebook(ipynb)
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Хорошее введение в проект - пригодится в будущем, когда соберешь большое портфолио и откроешь проект вновь👍
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
#загружаем датасет и используем разделитель(sep='\t'), чтобы увидеть данные в удобном виде таблицы,
#а не строки, как выводится изначально.
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

#выведем первые пять строк датафрейма и первично изучим данные.
print(data.head())

#получим информацию о типах данных в каждой колонке датафрейма.
print(data.info())

#построим общую гистограмму для всех числовых столбцов в таблице (17).
data.hist(figsize=(15, 20))

#Общая диаграмма размаха для оценки выбросов.
data.plot(kind='box', subplots=True, layout=(5,4), figsize=(15, 20));
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Предварительное изучение данных показывает, что мы имеем дело с датафреймом в котором 22 столбца с максимальным количеством строк равным 22699. Но стоит обратить внимание, что максимальное количество строк без пропусков наблюдается лишь в 8 столбцах из 22. Это может свидетельствовать о большом количестве пропусков в данных  и данный факт важно учитывать при последующей обработке данных.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Отлично👍 Приступаем к предобработке
#
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
#Посчитаем количество пропусков во всех столбцах.
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
#Изменим тип данных в столбце 'first_day_exposition'. Время откинем, оставим только дату.
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%d')#T%H:%M:%S')
#Фиксируем и проверяем наши изменения.
print(data.head())
data.info()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
print(data['ceiling_height'].min(), data['ceiling_height'].max(), data['ceiling_height'].median())
data['ceiling_height'].hist(bins=10, range=(0, 100), figsize=(7, 7))
# Out:
# 1.0 100.0 2.65
# <AxesSubplot:>

# %%
#Посчитаем процент пустых значенфий от общего числа.
len(data[data['ceiling_height'].isna()])/22699
# Out:
# 0.405083924401956

# %% [markdown]
# 40% процентов строк в столбце'ceiling_height' пустые. Поскольку данные о высоте потолка вносятся продавцом, то такое большое значение пропусков может говорить о том, что продавец либо не считает важным данное значение, либо не в силах измерить/выяснить высоту в продаваемой квартире (что довольно странно). Также такое количество пропусков могут указывать на ошибку при выгрузке данных. Заполним их медианными значениями, откинув выбросы.

# %%
#выведем уникальные значения столбца 'ceiling_height'.
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,    nan,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.65,   3.2 ,   2.61,
#          3.25,   3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,
#          3.3 ,   2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,
#          3.4 ,   3.06,   2.72,   2.54,   2.51,   2.78,   2.76,  25.  ,
#          2.58,   3.7 ,   2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,
#          2.45,   3.6 ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,
#          3.16,   3.62,   3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,
#          5.  ,   2.79,   2.95,   4.06,   2.94,   3.82,   3.54,   3.53,
#          2.83,   4.7 ,   2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,
#          3.18,   3.35,   2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,
#          2.63,   3.83,   3.52,   3.95,   3.75,   2.88,   3.67,   3.87,
#          3.66,   3.85,   3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера ⚠️**
#
#    При просмотре данных в этом столбце, не показалось ли тебе, что продавцы могли допустить опечатку? Можно ее исправить следующим образом:
#
# </div>

# %%
# Код ревьюера
#data.update(data[(data['ceiling_height'] >= 25) & (data['ceiling_height'] <= 36)]['ceiling_height']/10)

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера ⚠️**
#
#    А после этого можно заполнить пропуски медианой
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Я думал об этом и хотел исправить каждый блок значений,похожий на опечатку отдельно (через замену значений в столбце по условию). Но потом, когда я посчитал медиану, решил, что не будет так критично, если я заменю эти значения медианным, ведь таких значений всего 38. К тому же я не знал про такой элегантный метод update(), которым и воспользуюсь. Но дабы следовать в русле собственной логики, которую написал в ячейке ниже, я возьму более широкий диапазон (от 21 до 100), ведь потолок высотой 2.1 и 10 метров входят в релевантные значения.

# %% [markdown]
# При выводе уникальных значений столбца 'ceiling_height' видим значения, которые кажутся неправдоподобными: 27.5, 100, 20, 27,... Максимальная высота потолка в жилом помещении в квартире России, которую я нашел, равна 10.3 метра [ЖК «Арт Хаус»](https://elitnoe.ru/articles/991-top-5-elitnyh-kvartir-s-vysotoy-potolkov-ot-5-do-10-metrov/ 'Красиво жить не запретишь)'). Поэтому сделаем срез данных, взяв все потолки больше 10.3 метра. Тоже самое проделаем для потолков ниже 2.1 метра, что является минимальным значением потолка для жилых помещений в России [ссылка на ГОСТ](https://www.consultant.ru/document/cons_doc_LAW_58136/85f7dc8994f991a1132725df3886eeefc605e1b9/ "Смотри абзац №22").

# %%
#Заменим все высокие значения похожие на опечатку(от 21 до 100).
data.update(data[(data['ceiling_height'] >= 21) & (data['ceiling_height'] <= 100)]['ceiling_height']/10)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Также, если быть последовательным, то можно принять за опечатку (только в обратную сторону) все низкие значения, которые могут уложиться при изменении в диапазон до 10.3 метра.
#     <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Хорошее решение👍
#
# </div>

# %%
#Заменим все низкие значения до 1.03.
data.update(data[data['ceiling_height'] <= 1.03]['ceiling_height']*10)

# %%
#Делаем срез слишком высоких потолков и сортируем полученные данные по возрастанию.
#data.query('ceiling_height > 10.3').sort_values(by='ceiling_height')
data.loc[data['ceiling_height'] > 10.3].sort_values(by='ceiling_height')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 15061            19   5600000.0        56.4           2018-05-11      2
# 17496            15   6700000.0        92.9           2019-02-19      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 15061            14.0          14.0         32.4      5          NaN  ...
# 17496            20.0          17.0         53.2     14          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 15061           9.1      2.0  Санкт-Петербург           14814.0
# 17496          12.0      5.0  Санкт-Петербург           16295.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 15061             13610.0               0.0            NaN               0.0
# 17496             15092.0               1.0          967.0               0.0
#
#        ponds_nearest  days_exposition
# 15061            NaN            315.0
# ...

# %%
#Делаем срез для поиска низких потолков.
data.loc[data['ceiling_height'] < 2.1].sort_values(by='ceiling_height')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5712              5   1500000.0       42.80           2017-08-14      2
# 16934             5   4100000.0       40.00           2017-10-17      1
# 552              11   2999000.0       33.50           2017-03-30      1
# 2572              4   2400000.0       62.00           2018-12-27      3
# 4212              1   2120000.0       35.43           2017-12-18      1
# 5850              9   1650000.0       35.50           2018-05-29      1
# 11352             4   3300000.0       36.00           2017-06-18      1
# 16446             6  12300000.0       88.30           2019-03-12      3
# 16884             0   1500000.0       33.00           2018-10-03      1
# 19098             7   2700000.0       56.00           2018-02-04      3
# 19329             5   1700000.0       40.00           2018-07-15      2
# 20520             9   3600000.0       38.00           2018-07-05      1
# ...

# %% [markdown]
# У нас получилось 2 нестандартных значения превышающих высоту 10.3 метра и 13 значений ниже минимальной допустимой отметки для жилых посещений (2.1 метра). Рассчитаем медианную высоту потолка, исключив полученные выбросы.

# %%
#Посчитаем медиану столбца 'ceiling_height'без выбросов ниже 2.1 и выше 10.3.
ceiling_height_no_release= data.query('ceiling_height >= 2.1 and ceiling_height <= 10.3' )
#ceiling_height_no_release.info()
ceiling_height_median = ceiling_height_no_release['ceiling_height'].median()
ceiling_height_median
# Out:
# 2.65

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Прав ли я в том, что в следующем блоке кода удаляю все значения, выходящие за диапазон условия меданы? Или более целесообразно и эти значения заменить на медианные, тем более, что их совсем немного (всего 15 строк).
#     #data.update(data[(data['ceiling_height'] < 2.1) | (data['ceiling_height'] > 10.3)]['ceiling_height'] == ceiling_height_median)
#     <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Так как значений относительно всего датасета мало - можно удалить. Также рекомендую после завершения предобработки посмотреть, какую долю от исходного датасета мы оставили - важно, чтобы после удаления/замены осталось не менее 90% от исходных данных
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# В блоке ниже для экономии памяти изменим тип данных `ceiling_height` на float32.

# %%
print(data['ceiling_height'].isna().sum())
#Заменяем все пропуски в столбце 'ceiling_height' на медиану.
data['ceiling_height'] = data['ceiling_height'].fillna(ceiling_height_median)
#Проверяем, что пропусков больше нет.
print(data['ceiling_height'].isna().sum())
#Удаляем все значения, которые выбиваются из условия медианы.
data['ceiling_height'] = data.query('ceiling_height >= 2.1 and ceiling_height <= 10.3' )
data['ceiling_height'] = data['ceiling_height'].astype('float32')
data.info()
# Out:
# 9195
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23684 non-null  float32
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
# ...

# %%
#Проверим уникальные значния столбца 'floors_total'.
print(data['floors_total'].unique())
#Проверим минимальное и максимальные значения.
print(data['floors_total'].min())
print(data['floors_total'].max())
#Проверим дату самой последней публикации в датафрейме.
print(data['first_day_exposition'].max())
#На всякий случай посчитаем количество этажей больше 42.
(data.query('floors_total > 42').count())
#Посмотрим дату публикации объявления для двух выбросов.
data.query('floors_total == [52, 60]')
#Посчитаем медиану, посчитав за выбросы два значения больше 42 этажей.
floors_total_no_release = data.query('floors_total <= 42')
floors_total_median = floors_total_no_release['floors_total'].median()
print(floors_total_median)
#Заменяем все пропуски 
data['floors_total'] = data['floors_total'].fillna(floors_total_median)
#Проверяем количество пропусков в столбце 'floors_total'
print(data['floors_total'].isna().sum())
# Out:
# [16. 11.  5. 14. 12. 26. 24. 27.  9.  6. 17. 25.  3. 23. 19. 18.  4. 22.
#   8.  2. 10.  7. 13. 15. nan 20. 28. 36. 21. 35. 34. 60.  1. 29. 33. 52.
#  37.]
# 1.0
# 60.0
# 2019-05-03 00:00:00
# 9.0
# 0

# %% [markdown]
# В столбце 'floors_total' обнаружилось два значения, которые можно посчитать за выбросы (52 и 60), потому что
# дата публикаций данных объявлений 2018 год, но на тот момент самым высоким **действующим** зданием Санкт-Петербурга был БЦ 'Leader Tower' [ссылка](https://www.novostroy.su/articles/large-projects/bts-leader-tower-pervyy-postroennyy-i-vtoroy-skandalnyy-neboskreb-goroda/ ' Всего 42 этажа'). Одиозная 'Лахта-центр' высотой 88 этажей хоть и сдана в 2018 году, но в ней до сих пор не продаются квартиры в открытом доступе. Поэтому при рассчете медианы эти значения исключим, но их сами удалять не будем, поскольку они могут пригодиться в будущем анализе данных и свидетельствовать о мошенниках!
# ---
# Также ранее было видно, что тип данных в столбце 'floors_total' имеет значение 'float'. Вряд ли у нас может быть полтора или половина этажа, поэтому логично после удаления пропусков, привести все данные в этом столбце к целому числу.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Здесь у меня вопрос по выбросам: стоит ли два выбивающихся этажа удалить сразу или все-таки оставить строки с выбросами, ведь в них есть много полезных данных в других столбцах? Я в данном случае оставление этих данных оправдываю тем, что это могло быть опечаткой со стороны продавца. Еще был соблазн заменить их тоже медианным значением, но  передо мной встала диллема: с одной стороны я сохраняю данные, что увеличивает общий массив данных, а значит делает все выводы более точными, но с другой стороны я вношу преднамеренные искажения в данные. Как поступить в данном случае? И я понимаю, что если бы таких значений было много (более 10%), то я бы не стал менять значения! Или и тут я не прав?
#     <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Выбросы лучше удалить
#
# </div>

# %%
#Заменим тип данных в строках на int, вряд ли бывает полтора этажа)))
data['floors_total'] = data['floors_total'].astype('int')
#Проверим, что тип данных в столбце 'floors_total' поменялся.
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23684 non-null  float32
#  6   floors_total          23699 non-null  int64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
# ...

# %%
#Найдем количество пропусков встолбце 'living_area'.
print(len(data[data['living_area'].isna()]))
#Посчитаем процент пустых значений от общего числа.
len(data[data['living_area'].isna()])/22699
# Out:
# 1903
# 0.08383629234768052

# %% [markdown]
# Чуть больше 8% строк в столбе 'living_area' являются пустыми. Заполним эти значения медианными. За выбросы возьмем все значения ниже 12 кв. метров [почему?](https://moika78.ru/news/2019-01-14/175808-studiya-v-12-kvadratov-najdena-samaya-malenkaya-kvartira-peterburga/#:~:text=%D0%9D%D0%BE%20%D1%81%D0%B0%D0%BC%D0%B0%D1%8F%20%D0%B4%D0%B5%D1%88%D0%B5%D0%B2%D0%B0%D1%8F%20%D0%BC%D0%B8%D0%BD%D0%B8%2D%D0%BA%D0%B2%D0%B0%D1%80%D1%82%D0%B8%D1%80%D0%B0,%D1%80%D1%83%D0%B1%D0%BB%D0%B5%D0%B9./ 'Смотри здесь') и значения больше 200, потому что по гистограмме видно,все что выше часто имеет единичные значения.

# %%
data['living_area'].hist(bins=50, range=(2, 410), figsize=(7, 7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Попробуем вычислить жилую площадь. Нужно найти **соотношение медианной общей площади к медианной жилой**. А затем, заполнить пропуски в столбце `living_area` **отношением общей площади к найденному соотношению**.
#
# </div>

# %%
#Находим отношение площадей: жилой к общей.
ratio_total_to_living = data['total_area'].median() / data['living_area'].median()
print(ratio_total_to_living)
# Out:
# 1.7333333333333334

# %%
#Заменим все пустые площади квартир.
data.update(data['living_area'].fillna(data['total_area'] / ratio_total_to_living))
print(data.isna().sum())

#Изменим тип данных для экономии памяти.
data['living_area'] = data['living_area'].astype('float32')
#Проверим тип данных в столбце.
data.living_area.dtype
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height             15
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
# dtype('float32')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Здесь у меня вопрос:** почему при проверке пустых значений `living_area`, в столбце `ceiling_height` появилось пустые значения, хотя при проверке пустых значений в  `ceiling_height` выше, все было ОК и количество пустых значений было равно нулю?
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера v2⚠️**
#
#    Здесь также при замене лучше воспользоваться методом update - тогда пропуски заполнятся
#
# </div>

# %%
# Код ревьюера
data['living_area'].isna().sum()
# Out:
# 0

# %%
#Рассчитаем медиану в нефильтрованных данных.
print(data['living_area'].median())
#print(data['living_area'].mean())
print(data['living_area'].max())
print(data['living_area'].min())
data['living_area'].sort_values()

#Находим все квартиры площадью больше 12 метров и меньше 200.
#living_area_no_relise = data.query('living_area >=12 and living_area <=200')
#living_area_no_relise

#Находим медианнное значение.
#living_area_median = living_area_no_relise['living_area'].median()
#print(living_area_median)

#Удалим все значения ниже 12 кв. метров.
data['living_area'] = data.query('living_area > 12') 
data['living_area'].count().sum()
# Out:
# 30.0
# 409.7
# 2.0
# 23520

# %%
#Заменил все пустые площади квартир медианным значением.
#data['living_area'] = data['living_area'].fillna(living_area_median)
#data.isna().sum()

# %%
#Проверим столбец 'is_apartment'.
data['is_apartment'].unique()
#В столбце булевы значения. Логично предположить, что пропуски - это False.
#Заменим пропуски на ноль.
data['is_apartment'] = data['is_apartment'].fillna('False')
data['is_apartment'].isna().sum()
# Out:
# 0

# %%
#Найдем количество пропусков встолбце 'kitchen_area'.
print(len(data[data['kitchen_area'].isna()]))
len(data[data['kitchen_area'].isna()])/22699
# Out:
# 2278
# 0.1003568439138288

# %% [markdown]
# 10% процентов продавцов не посчитали нужным указать площадь кухни. Вероятно у них были на то веские причины. Рассчитаем медианное значение и заменим им все пустые строки.

# %%
#Рассчитаем предварительные пиковые и средние значения.
print(data['kitchen_area'].min())
print(data['kitchen_area'].max())
print(data['kitchen_area'].mean())
print(data['kitchen_area'].median())
#То же самое, но одной строкой.
data['kitchen_area'].describe()
# Out:
# 1.3
# 112.0
# 10.569807198543485
# 9.1
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
data['kitchen_area'].hist(bins=100, range=(1, 115), figsize=(8, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Заменим все пропущенные значения в столбце `kitchen_area` на отношение общей площади к результату отношения медианной общей площади к медианной жилой площади.

# %%
#Рассчитаем коэффициент отношения общей медианной площади к медианной жилой площади.
ratio_total_to_kitchen = data['total_area'].median() / data['kitchen_area'].median()
ratio_total_to_kitchen
# Out:
# 5.714285714285714

# %%
#kitchen_area_no_relise = data.loc[(data['kitchen_area']>=5) & (data['kitchen_area']<=50)]
#kitchen_area_no_relise
#kitchen_area_median = kitchen_area_no_relise['kitchen_area'].median()
#print(kitchen_area_median)
#Заполним пропуски.
data['kitchen_area'] =data['kitchen_area'].fillna(data['total_area'] / ratio_total_to_kitchen)
print(data.isna().sum())
#Изменим тип данных для экономии памяти.
data['kitchen_area'] =data['kitchen_area'].astype('float32')
data.kitchen_area.dtype
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height             15
# floors_total                0
# living_area               179
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
# dtype('float32')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Здесь почти продублирую вопрос, который задавал выше:** почему в `living_area` , в котором выше было нулевое количество пропусков, сейчас они есть (179)? Я делал перезапуск всех ячеек через кнопку в панели. Но потом, когда перезапускаю эту ячейку, то все становится нормально или выскакивает другое значение пропусков.

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера ⚠️**
#
#    Как альтернатива:
# По столбцу `living_area` - иногда продавцы могут не указывать данное значение, однако, мы можем попробовать его вычислить. Нужно найти **соотношение медианной общей площади к медианной жилой**. А затем, заполнить пропуски в столбце `living_area` **отношением общей площади к найденному соотношению**.
#
# Со столбцом `kitchen_area` можно поступить так же, как со столбцом `living_area`.
#
# </div>

# %%
#Найдем количество пропусков встолбце 'balcony'.
print(len(data[data['balcony'].isna()]))
#Посчитаем процент пустых значений от общего числа.
len(data[data['balcony'].isna()])/22699
# Out:
# 11519
# 0.507467289307899

# %% [markdown]
# Ого! 50% продавцов не заполнили поле о наличии и количестве балконов. Логично предположить, что у них просто нет балкона, поэтому заменим пропуски числовым значением '0'

# %%
#Выведем уникальные значения столбца 'balcony'.
print(data['balcony'].unique())

#Заменим все пропуски на "0"
data['balcony'] = data['balcony'].fillna(0)

#Проверим, что все заменилось.
print(data['balcony'].unique())

#Заменим тип данных в строках на int, вряд ли бывает полтора балкона)))
data['balcony'] = data['balcony'].astype('int')

#Проверим, что тип данных в столбце 'balcony'поменялся.
print(data.balcony.dtype)

#Проверим количество пропусков после всех замен
#len(data[data['balcony'].isna()])
data['balcony'].isna().sum()
# Out:
# [nan  2.  0.  1.  5.  4.  3.]
# [0. 2. 1. 5. 4. 3.]
# int64
# 0

# %%
#Выведем уникальные имена названий
data['locality_name'].value_counts()
print(len(data['locality_name'].unique()))
#data['locality_name'] = data['locality_name'].str.lower()
print(data['locality_name'].unique())
#data['locality_name'].astype(str)
#data.info()
# Out:
# 365
# ['Санкт-Петербург' 'посёлок Шушары' 'городской посёлок Янино-1'
#  'посёлок Парголово' 'посёлок Мурино' 'Ломоносов' 'Сертолово' 'Петергоф'
#  'Пушкин' 'деревня Кудрово' 'Коммунар' 'Колпино'
#  'поселок городского типа Красный Бор' 'Гатчина' 'поселок Мурино'
#  'деревня Фёдоровское' 'Выборг' 'Кронштадт' 'Кировск'
#  'деревня Новое Девяткино' 'посёлок Металлострой'
#  'посёлок городского типа Лебяжье' 'посёлок городского типа Сиверский'
#  'поселок Молодцово' 'поселок городского типа Кузьмоловский'
#  'садовое товарищество Новая Ропша' 'Павловск' 'деревня Пикколово'
#  'Всеволожск' 'Волхов' 'Кингисепп' 'Приозерск' 'Сестрорецк'
#  'деревня Куттузи' 'посёлок Аннино' 'поселок городского типа Ефимовский'
#  'посёлок Плодовое' 'деревня Заклинье' 'поселок Торковичи'
#  'поселок Первомайское' 'Красное Село' 'посёлок Понтонный' 'Сясьстрой'
#  'деревня Старая' 'деревня Лесколово' 'посёлок Новый Свет' 'Сланцы'
#  'село Путилово' 'Ивангород' 'Мурино' 'Шлиссельбург' 'Никольское'
# ...

# %%
#Устраним неявные дубликаты в названиях объектов.
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
data['locality_name'] = data['locality_name'].str.replace('городской поселок', 'поселок городского типа')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок при железнодорожной станции', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('садоводческое некоммерческое товарищество', 'садовое товарищество')
len(data['locality_name'].unique())
# Out:
# 323

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#
#    Также рекомендую хорошую статью по предобработке, в ней есть интересные способы обработки неявных дубликатов: https://proglib.io/p/moem-dataset-rukovodstvo-po-ochistke-dannyh-v-python-2020-03-27
#
# </div>

# %% [markdown]
# ***Мы добрались до картографических данных. Они добавляются НЕ пользователем, а высчитываются сервисом. Настораживает очень похожее количество пропусков в 4-х столбцах ( чуть больше 5500 значений) и также очень близкие по количеству пропусков значения в столбцах 'parks_nearest' и 'ponds_nearest'. Очень похоже на ошибку выгрузки данных, поэтому попробуем заполнить пропуски в этих столбцах.***

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height             15
# floors_total                0
# living_area               179
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23684 non-null  float32
#  6   floors_total          23699 non-null  int64
#  7   living_area           23520 non-null  object
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float32
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %%
#Проверим на пустые строки столбец 'airports_nearest'.
print(len(data[data['airports_nearest'].isna()]))
#Посчитаем процент пустых значений от общего числа.
len(data[data['airports_nearest'].isna()])/22699
# Out:
# 5542
# 0.2441517247455835

# %% [markdown]
# В столбце 'airports_nearest' 24% пустых значений. Думаю, что стоит заполнить все пропуски медианным значением всех известных данных.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Не будем заполнять пропуски в столбце `airports_nearest`, в будущем он нам не понадобится, оставим все как есть.

# %%
data['airports_nearest'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
#Рассчитаем медиану для исходных данных.
median_airports_nearest = data['airports_nearest'].median()
print(median_airports_nearest)
data['airports_nearest'].describe()

#Удалим строку с нулевым значением, квартира не может быть в аэропорту.
#data = data[data.airports_nearest > 6000]

#Проверим данные на минимальные.
print(data['airports_nearest'].min())

#Теперь заменим все пропуски
#data['airports_nearest'] = data['airports_nearest'].fillna(median_airports_nearest)

#Проверка.
#data['airports_nearest'].isna().sum()
# Out:
# 26726.0
# 0.0

# %%
print(data['cityCenters_nearest'].describe())
data['cityCenters_nearest'].hist(bins=100, range=(0, 75000), figsize=(7, 7))
# Out:
# count    18180.000000
# mean     14191.277833
# std       8608.386210
# min        181.000000
# 25%       9238.000000
# 50%      13098.500000
# 75%      16293.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# На графике видно фактически 7 пиковых значений, это может говорить о том, что в данных присутствует семь категорий населенных пунктов с разным расстоянием до центра города. Поэтому желательно разбить значения на 7 подгрупп и для каждой рассчитать свою медиану, которую затем подставлять вместо пропущенных значений в каждой подгруппе.
#
# | Диапазон_значений | Название_категории |
# |:---|:---|
# 1. от 0 до 8000 метров|       **up_8000**
# 2. от 8000 до 20000 метров|   **up_20000**
# 3. от 20000 до 25000 метров|  **up_25000**
# 4. от 25000 до 37500 метров|  **up_37500**
# 5. от 38800 до 43300 метров|  **up_43300**
# 6. от 45000 до 55000 метров|  **up_55000**
# 7. выше 55000 метров|         **up_70000**

# %%
#Создаем функцию, которая разделит данные на 7 категорий.
def cityCenters_near_category(cityCenters_nearest):
    if cityCenters_nearest <= 8000:
        return 'up_8000'
    if cityCenters_nearest <=20000:
        return 'up_20000'
    if cityCenters_nearest <=25000:
        return 'up_25000'
    if cityCenters_nearest <= 37500:
        return 'up_37500'
    if 38800 <= cityCenters_nearest <= 43300:
        return 'up_43300'
    if 45000 <= cityCenters_nearest <= 55000:
        return 'up_55000'
    if cityCenters_nearest > 55000:
        return 'up_70000'
    
#Проверяем работу функции.
cityCenters_near_category(65000)

#Создаем в таблице столбец с категориями 'cityCenters_near_category'.
#data['cityCenters_near_category'] = data['cityCenters_nearest'].apply(cityCenters_near_category)
#data.head()

#Посчитаем количество значений по каждой категории.
#print(data['cityCenters_near_category'].value_counts())

#Заполним медианным значением по каждой категории пропуски в столбце 'cityCenters_nearest'.
#for value in data['cityCenters_near_category'].unique():
#    data.loc[(data['cityCenters_near_category'] == value) & \
#            (data['cityCenters_nearest'].isna()), 'cityCenters_nearest'] = \
#    data.loc[(data['cityCenters_near_category'] == value), 'cityCenters_nearest'].median()
    
#Проверяем пустые значения в столбце 'cityCenters_nearest'
#data['cityCenters_nearest'].isna().sum()
#data[data['cityCenters_nearest'].isin(['NaN'])]
# Out:
# 'up_70000'

# %% [markdown]
# Все что я написал выше про столбец 'cityCenters_nearest' полная ересь. Найдем медиану и подстьавим в пустые значения.

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера ⚠️**
#
#    Касательно геоданных - эти выборки имеют довольно большой разброс. Поэтому при работе с ними необходимо смотреть, насколько вообще эти данные нам будут нужны при дальнейшем анализе? Далее по проекту бОльшая часть столбцов с геоданными нам не понадобится - поэтому можно оставить пропуски без изменений. Иногда это лучше, чем заполнять пропуски данными, которые на деле могут оказаться неактуальны
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Полностью согласен. По геоданным нам будут нужны только значения с расстоянием до центра города в км. Поэтому только в этом столбце стоит заполнить пропуски медианным значением. Все остальные оставить как есть.
#     <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    👍
#
# </div>

# %%
data['cityCenters_nearest'].plot(kind='box')
cityCenters_nearest_median = data['cityCenters_nearest'].median()
data['cityCenters_nearest'] = data['cityCenters_nearest'].fillna(cityCenters_nearest_median)
data['cityCenters_nearest'].isna().sum()
# Out:
# 0

# %%
print(data['parks_around3000'].describe())
data['parks_around3000'].hist(bins=10, range=(0, 3),)
# Out:
# count    18181.000000
# mean         0.611408
# std          0.802074
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# Name: parks_around3000, dtype: float64
# <AxesSubplot:>

# %%
#data.dtypes
#print(data['parks_around3000'].value_counts())
#data['parks_around3000'] = data['parks_around3000'].fillna(0)
#data.isna().sum()

# %% [markdown]
# Опираясь на известные данные, можно предположить, что все пропущенные значения равны нулевому количеству парков в окрестностях, что вполне логично, ведь у нас данные по Ленинградской области где много небольших городов в окружении естественной природы.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# В `parks_around3000`тоже ничего не меняем, этот столбец нам НЕ нужен в будущем исследовании.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height             15
# floors_total                0
# living_area               179
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest         0
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
#Рассмотрим столбец 'parks_nearest'.
print(data['parks_nearest'].describe())
data['parks_nearest'].plot(kind='box')
#Заполним медианными значениями все пропуски.
#data['parks_nearest'] = data['parks_nearest'].fillna(455)
#data['parks_nearest'].isna().sum()
# Out:
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64
# <AxesSubplot:>

# %%
# Рассмотрим столбец 'ponds_around3000'.
data['ponds_around3000'].hist()
#По гистограмме видно, что преобладают нулевые значения,
#поэтому просто заменим все пропуски на нули.
#data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
#data['ponds_around3000'].isna().sum()
# Out:
# <AxesSubplot:>

# %%
print(data['ponds_nearest'].describe())
data['ponds_nearest'].hist(bins=100, range=(10, 1400))
#Заполним пропуски числовым значением медианы.
#data['ponds_nearest'] = data['ponds_nearest'].fillna(502)
#data['ponds_nearest'].isna().sum()
# Out:
# count    9110.000000
# mean      517.980900
# std       277.720643
# min        13.000000
# 25%       294.000000
# 50%       502.000000
# 75%       729.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64
# <AxesSubplot:>

# %%
#Проверим столбец 'days_exposition'.
data['days_exposition'].hist(bins=50, range=(0, 1700), grid=True, figsize=(7, 7))
#data['days_exposition'].plot(kind='box')
#days_exposition_median = data['days_exposition'].median()
#data['days_exposition'] = data['days_exposition'].fillna(days_exposition_median)
data['days_exposition'].isna().sum()
# Out:
# 3181

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23684 non-null  float32
#  6   floors_total          23699 non-null  int64
#  7   living_area           23520 non-null  object
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float32
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %%
#Создаем столбец с годом размещения объявления.
data['year'] = data['first_day_exposition'].dt.year
#Создаем сводную таблицу с количеством пропусков по годам.
data.query('days_exposition.isna()').pivot_table(index='year', values='last_price', aggfunc='count')
# Out:
#       last_price
# year
# 2014          18
# 2015          70
# 2016          67
# 2017         271
# 2018         959
# 2019        1796

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# По сводной таблице видно, что количество пропусков растет прямопропорционально году. Это свидетельствует о том, что пропуски за 2019 год, почти наверняка, не случайны, а говорят о том, что данные квартиры еще не проданы и выставляются для продажи на момент выгрузки данных. Оценивая цифру пропусков, тоже самое можно сказать про 2018 год. А начиная с 2017 года все пропуски можно отнести к случайным, поскольку их меньше по сравнению с 2018 почти в **четыре раза**, в то время как количество пропусков в 2018 меньше пропусков в 2019 в **два раза**. Также, можно предположить, что продажа квартиры более двух лет, является избыточным сроком для положительного решения. Такие квартиры разумнее снять с продажи, либо существенно подкорректировать объявление. Поэтому заполним медианным значением пропуски с 2014 по 2017 годы, оставив без изменений пропуски за 2018 и 2019 годы.
#     <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Хорошо
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    По столбцу `days_exposition` - Мы можем заполнять только те данные, которые пропущенны совершенно случайно. Иначе заполнение может повлиять на характер связи между заполняемой величиной и остальными. Попробуй рассмотреть распределение пропусков в данном столбце относительно года выставления квартиры на продажу. Какой вывод ты сможешь сделать? Являются ли данные пропуски случайными?
#
# </div>

# %%
#Рассчитаем количество пропусков в столбце 'days_exposition'.
print(data['days_exposition'].isna().sum())
#Рассчитаем медиану до 2017 года.
until_2017 = data.query('year <= 2017')
until_2017_median = until_2017['days_exposition'].median()
print(f'Медиана равна: {until_2017_median}')
#Заполним пропуски до 2017 года включительно.
for i in data['days_exposition']:
    data.loc[(data['year']<=2017) & (data['days_exposition'].isna()), \
             'days_exposition'] = data['days_exposition'].fillna(until_2017_median)
#Проверяем пропуски. У нас должно остаться 2755 (за 2018 и 2019 годы):
data['days_exposition'].isna().sum()
# Out:
# 3181
# Медиана равна: 154.0
# 2755

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height             15
# floors_total                0
# living_area               179
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest         0
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          2755
# year                        0
# dtype: int64

# %%
#Удаляем  пропуски в'locality_name' и сбрасываем индексы.
data['locality_name'] = data['locality_name'].dropna()
data = data.reset_index(drop=True)
data.head()
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height             15
# floors_total                0
# living_area               179
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest         0
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          2755
# year                        0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# ✔️ Комментарий ревьюера ✔️
#
# В целом, работа по предобработке проведена очень качественно. Можно еще сэкономить память, изменяя типы данных. Например, дополнительно изменить их у площадей квартир с float64 на float32.
#
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
#Считаем цену одного квадратного метра.
data['price_meter'] = data['last_price'] / data['total_area']
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total living_area  floor is_apartment  ...  \
# 0            20.0            16        20.0      8        False  ...
# 1             7.0            11         7.0      1        False  ...
# 2            10.0             5        10.0      4        False  ...
# 3             0.0            14         0.0      9        False  ...
# 4             2.0            14         2.0     13        False  ...
#
#      locality_name  airports_nearest  cityCenters_nearest  parks_around3000  \
# ...

# %%
#Создаем столбцы с днем недели, месяцем.# и годом публикации объявления.
data['weekday'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
#data['year'] = data['first_day_exposition'].dt.year
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total living_area  floor is_apartment  ...  \
# 0            20.0            16        20.0      8        False  ...
# 1             7.0            11         7.0      1        False  ...
# 2            10.0             5        10.0      4        False  ...
# 3             0.0            14         0.0      9        False  ...
# 4             2.0            14         2.0     13        False  ...
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %%
#Добаляем столбец с типом этажа квартиры 'type_floor'.
#Создаем функцию, которая задаст этажам категорию по условию.
def type_floor_func(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
data['type_floor'] = data.apply(type_floor_func, axis=1)
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total living_area  floor is_apartment  ...  \
# 0            20.0            16        20.0      8        False  ...
# 1             7.0            11         7.0      1        False  ...
# 2            10.0             5        10.0      4        False  ...
# 3             0.0            14         0.0      9        False  ...
# 4             2.0            14         2.0     13        False  ...
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0               1.0          482.0               2.0          755.0
# ...

# %%
#Добавим столбец с расстоянием до центра города в км.
data['cityCenters_near_km'] = data['cityCenters_nearest'] / 1000
#Удалим столбец 'cityCenters_near_category',созданный ранее, он не нужен.
#data.drop('cityCenters_near_category', axis= 1, inplace= True )
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total living_area  floor is_apartment  ...  \
# 0            20.0            16        20.0      8        False  ...
# 1             7.0            11         7.0      1        False  ...
# 2            10.0             5        10.0      4        False  ...
# 3             0.0            14         0.0      9        False  ...
# 4             2.0            14         2.0     13        False  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest  days_exposition  year  \
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    В данном блоке все верно
#
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %%
#Изучаем общую площадь.
print(data['total_area'].describe())
data['total_area'].hist(bins=100, range=(12, 250))
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# Гистограмма имеет вид распределения Пуассона, что нормально. По гистограме видно, что основное количество значений находится в диапазоне от 30 до 100 кв. метров.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Почему в блоке ниже метод describe() не показал то, что должен (среднее, медиана, мин и мах...)?
#     <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера v2⚠️**
#
#    Вот хорошее объяснение: https://stackoverflow.com/questions/38433672/pandas-describe-only-returning-4-statistics-on-int-dataframe-count-unique
#
# </div>

# %%
#Исследуем жилую площадь.
print(data['living_area'].describe())
data['living_area'].hist(bins=100, range=(0, 50))
data['living_area'].value_counts()
# Out:
# count     23520.0
# unique       38.0
# top          10.0
# freq       1776.0
# Name: living_area, dtype: float64
# 10.0    1776
# 9.0     1708
# 20.0    1685
# 8.0     1573
# 7.0     1505
# 6.0     1469
# 11.0    1357
# 5.0     1291
# 12.0    1218
# 0.0     1053
# 13.0    1010
# 4.0      977
# 14.0     976
# 15.0     942
# 1.0      863
# 3.0      763
# 16.0     759
# 17.0     649
# 18.0     638
# 2.0      632
# 19.0     601
# 23.0      16
# 21.0      12
# 24.0       8
# 22.0       8
# 26.0       5
# 28.0       4
# 32.0       4
# 29.0       3
# 50.0       3
# 27.0       2
# 30.0       2
# 31.0       2
# 35.0       2
# 25.0       1
# 37.0       1
# 39.0       1
# 42.0       1
# Name: living_area, dtype: int64

# %%
data['living_area'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# По графикам и числовым данным видно, что довольно большой процент данных равен нулю, что должно насторожить, ведь как в квартире
# жилая площадь может быть равна нулю?

# %%
#Исследуем площадь кухни.
print(data['kitchen_area'].describe())
data['kitchen_area'].hist(bins=50, range=(0, 120))
# Out:
# count    23699.000000
# mean        10.505496
# std          6.039401
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# С площадью кухни все в порядке. График имеет ожидаемый вид распределения. Медианная площадь кухни соответствует
# типичным срандартам для квартир России.

# %%
#Изучим стоимость объекта.
print(data['last_price'].describe())
data['last_price'].hist(bins=100, range=(100000, 10000000))
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# График показывает, что медианная стоимость квартир чуть меньше 5 млн. рублей.

# %%
#Исследуем количество комнат.
print(data['rooms'].describe())
data['rooms'].hist(bins=50, range=(1, 9))
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видно, что в Питербурге при продаже преобладают одно и двухкомнатные квартиры. С небольшим отставанием от них
# идут трехкомнатные. Все стандартно, как и в остальных крупных городах России.

# %%
#Изучим высоту потолков
print(data['ceiling_height'].describe())
data['ceiling_height'].hist(bins=10, range=(0, 11))
# Out:
# count    23684.000000
# mean         9.859778
# std          5.682463
# min          0.000000
# 25%          6.000000
# 50%          9.000000
# 75%         14.000000
# max         50.000000
# Name: ceiling_height, dtype: float64
# <AxesSubplot:>

# %%
data['ceiling_height'].plot(kind='box', figsize=(7, 7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Гистограмма высоты потолков показывает какую-то дичь, потому-что при предобработке данных она была совершенно нормальной. Сейчас она демонстрирует, что потолки с высотой 10.3 м преобладают.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Почему здесь доминирует потолок высотой 10.3 метров? На этапе предобработки все было нормально же!!!
#     <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Да, jupyter явно чудит. Рекомендую ознакомиться со статьей по интерпретации боксплотов: https://tidydata.ru/boxplot
#
# </div>

# %%
#Изучим этаж квартиры.
print(data['floor'].describe())
data['floor'].hist(bins=100, range=(1, 33))
# Out:
# count    23699.000000
# mean         5.892358
# std          4.885249
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# По диаграмме видно, что доминируют квартиры с этажностью от 1 до 5, что говорит нам о том, что большинство выставленных на продажу квартир расположены в так называемых хрущевках.

# %%
#Изучим квартиры по типу этажа.
print(data['type_floor'].value_counts())
data['type_floor'].hist(bins=10)
# Out:
# другой       17441
# последний     3341
# первый        2917
# Name: type_floor, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# Количество продаваемых квартир на первом и последних этажах пример равны и составляют примерно треть от продаваемых квартир.

# %%
#Изучение этажности домов.
print(data['floors_total'].describe())
data['floors_total'].hist(bins=100, range=(1, 60))
# Out:
# count    23699.000000
# mean        10.667750
# std          6.585961
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64
# <AxesSubplot:>

# %% [markdown]
#  По гистограмме видно, что преобладают пятиэтажки и девятиэтажки, что говорит о том, что в основном продаются дома советской постройки.

# %%
#Расстояние до центра города в метрах.
data['cityCenters_nearest'].describe()
data['cityCenters_nearest'].hist(bins=100, range=(181, 66000))
# Out:
# <AxesSubplot:>

# %% [markdown]
# На графике видно фактически 7 пиковых значений, это может говорить о том, что в данных присутствует семь категорий населенных пунктов с разным расстоянием до центра города, что нормально, ведь у нас представленны города и из Ленинградской области.

# %%
#Расстояние до ближайшего аэропорта.
print(data['airports_nearest'].describe())
data['airports_nearest'].hist(bins=100, range=(0, 85000))
# Out:
# count    18157.000000
# mean     28793.672193
# std      12630.880622
# min          0.000000
# 25%      18585.000000
# 50%      26726.000000
# 75%      37273.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# Из графика видно, что города в ленинградской области находятся на достаточном удалении от аэропортов.
# А несколько пиков на графике может свидетельствовать о том, что имеется несколько аэропортов.
# Также можно сказать, что в Санкт-Петербурге аэропорты находятся ближе к границам города, либо за его чертой.

# %%
#Расстояние до ближайшего парка.
print(data['parks_nearest'].describe())
data['parks_nearest'].hist(bins=100, range=(450, 470))
# Out:
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# У нас есть пиковое значение в 455 метров, что может указывать на то, что это объявления о продаже квартир в
# достаточно зеленом городе, в Санкт-Петербурге!

# %%
#День публикации объявления.
print(data['weekday'].describe())
data['weekday'].hist(bins=70, range=(0,6))
# Out:
# count    23699.000000
# mean         2.569307
# std          1.789082
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max          6.000000
# Name: weekday, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# Видно, что пик публикации объявлений приходится на вторник и четверг, а в выходные продавцы квартир предпочитают отдыхать. Это может говорить о том, что основная масса квартир продается риэлторами, а не собственниками.

# %%
#Исследует продажи по месяцам.
print(data['month'].describe())
data['month'].hist(bins=120, range=(1, 12))
# Out:
# count    23699.000000
# mean         6.400101
# std          3.491561
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%         10.000000
# max         12.000000
# Name: month, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# По гистограмме видно, что пик продаж приходится на конец зимы - начало весны, а начиная с мая по август на рынке недвижимости наблюдается спад.

# %% [markdown]
# <div class="alert alert-success">
# ✔️ Комментарий ревьюера ✔️
#
# Хороший результат. Хочу добавить, что обычно размеры двухкомнатных квартир составляют от 50 до 100 квадратных метров, что и соответствует проведенному анализу.
#
# Могу посоветовать на будущее хорошую статью по оформлению графиков:
#     https://devpractice.ru/matplotlib-lesson-3-3-text-elements/
#
#
#
# </div>

# %%
#Выясним скорость продажи квартир.
print(data['days_exposition'].describe())
data['days_exposition'].hist(bins=100, range=(0, 400), figsize=(7, 7))

#data['days_exposition'].plot(kind='box', subplots=True, figsize=(7, 7))
# Out:
# count    20944.000000
# mean       180.341721
# std        217.514892
# min          1.000000
# 25%         45.000000
# 50%         99.000000
# 75%        226.250000
# max       1580.000000
# Name: days_exposition, dtype: float64
# <AxesSubplot:>

# %% [markdown]
#
# Если квартира продается в течение первых 46 дней, то такие продажи можно считать быстрыми. В среднем (медиана) квартиры продаются в два раза дольше. Если квартира продалась в течение 200 дней, то этот результат можно считать приемлемым. Если же квартира стоит дольше 200 дней, то это повод задуматься об изменении условий продажи или же рекламе своего объявления.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Медианное время продажи квартиры составляет почти 100 дней, в то время, как **среднее** время продажи почти в два раза больше (180). По графику видно, что после 100 дней количество проданных квартир стремительно снижается (за исключением пика на 154 днях), что свидетельствует о том, что спрос на квартиры, находящиеся на сайте чуть больше трез месяцев падает. Данный факт, в свою очередь, является поводом для снижения стоимости квартиры, либо для изменения ее описания.
#     <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Хорошо
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Стоит пересмотреть этот вывод после исправления ошибок на этапе предобработки
#
# </div>

# %%
#Исследуем влияние отдельных данных на стоимость квартиры.
data_price_total_area = data.pivot_table(index='total_area', values='last_price')
data_price_total_area.plot(style='o', grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='total_area'>

# %%
data.pivot_table(index='living_area', values='last_price').plot(style='x-', grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='living_area'>

# %%
data.pivot_table(index='kitchen_area', values='last_price').plot(style='o', grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='kitchen_area'>

# %%
data.pivot_table(index='rooms', values='last_price').plot(style='o-', grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
data.pivot_table(index='type_floor', values='last_price').plot(style='o-', grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='type_floor'>

# %%
data.pivot_table(index='weekday', values='last_price').plot(style='o-', grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='weekday'>

# %%
data.pivot_table(index='month', values='last_price').plot(style='o-', grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
data.pivot_table(index='year', values='last_price').plot(style='o-', grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Квартиры расположенные выше, стоят дороже. Также особенно дорого стоят квартиры размещенные в декабре, учитывая, что из анализа предыдущих данных видно, что продать квартиру меньше, чем за два месяца это быстро, а пик продаж приходится на конец феврвля, то все объяснимо. Общая площадь показывает линейную зависимость стоимости квартиры от ее стоимости.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Хорошие результаты. Отмечу, что скорее всего, низкую цену на квартиры на первых этажах можно аргументировать плохими условиями - шум от улиц и охлаждаемость помещения зимой.
#
# </div>

# %%
#Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.
top_10 = data['locality_name'].value_counts()[0:10].index
print(top_10)
data.query('locality_name in @top_10').pivot_table(index='locality_name', values='last_price', aggfunc='mean')
# Out:
# Index(['Санкт-Петербург', 'поселок Мурино', 'поселок Шушары', 'Всеволожск',
#        'Пушкин', 'Колпино', 'поселок Парголово', 'Гатчина', 'деревня Кудрово',
#        'Выборг'],
#       dtype='object')
#                      last_price
# locality_name
# Всеволожск         3.789068e+06
# Выборг             3.250983e+06
# Гатчина            3.488337e+06
# Колпино            3.964021e+06
# Пушкин             6.469036e+06
# Санкт-Петербург    8.062507e+06
# деревня Кудрово    4.234158e+06
# поселок Мурино     3.652361e+06
# поселок Парголово  4.488075e+06
# поселок Шушары     4.108082e+06

# %% [markdown]
# Опираясь на таблицу средней стоимости кв. метра в 10-ти самых упоминаемых населенных пунктах, видно, что самая низкая стоимость кв. метра в Ломоносове, а самая высокая ожидаемо в Санкт-Петербурге.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Верно
#
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23684 non-null  float32
#  6   floors_total          23699 non-null  int64
#  7   living_area           23520 non-null  object
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float32
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %%
#Считаем стоимость каждого кв. км. для СПб.
#Срезом находим квартиры только в СПб.
spb_only = data.query('locality_name == "Санкт-Петербург"')
#Считаем среднюю стоимость км.
spb_costs_km = spb_only.pivot_table(index='cityCenters_near_km', values='last_price', aggfunc='mean')
spb_costs_km.plot(style='o', grid=True, figsize=(15, 10))
# Out:
# <AxesSubplot:xlabel='cityCenters_near_km'>

# %% [markdown]
# Стоимость многих квартир в пределах 10 км. от центра СПб выше квартир,расположенных дальше.

# %% [markdown]
# <div class="alert alert-success">
# ✔️ Комментарий ревьюера ✔️
#
# Верно. На графике после 7 км заметно, что цена меняется. Это возможный центр города.
#
# Если интересно, то самый дорогой по стоимости жилья район в Санкт-Петербурге риелторы назвали "Золотой треугольник". Дома "Золотого треугольника" находятся в пределах Невского проспекта, набережной реки Фонтанки и Дворцовой набережной.
# Для географической справки: https://zen.yandex.ru/media/id/5cb4ebcc0a51a300b5b1f60d/zolotoi-treugolnik-sanktpeterburga-chto-eto-i-gde-nahoditsia-5edf942db1204610073e88b2
#
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# На основе проведенного анализа можно сделать вывод, что наибольшее количество объектов недвижимости продается в Санкт-Петербурге. Также, тут и самое дорогое жилье из представленных городов. В среднем стоимость кв. метра жилья в санкт-Петербурге в **два раза** выше, чем в других населенных пунктах Ленинградской области (разве, что город Пушкин выбивается из этого правила, но название обязывает - Пушкин наше все!). На рынке доминируют предложения квартир в домах, вероятно, советской постройки от 5 до 9 этажей. Последний этаж и общая площадь наиболее значительно влияют на стоимость квартиры. Также существенно на стоимость квартир в Санкт-Петербурге влияет расположение объекта недвижимости (объекты в радиусе 7 км от центра стоят дороже). Главный пик продаж в регионе наблюдается в конце зимы-начале весны, что вполне объяснимо - пережить зиму в Петербурге есть целое испытание, которое после пережитого заставляет задуматься об улучшении жилищных условий!) Второй пик начинается осенью, в предверии зимы.) В это время наблюдаются самые высокие цены на жилье (сентябрь и декабрь). Стоимость квартир с 2014 до 2018 неуклонно падала и за 4 года упала **ВДВОЕ**! Наиболее выгодные варианты стоит смотреть во вторник, пятницу и воскресенье, а вот в субботу лучше устроить Шаббат!) Количество комнат линейно влияет на стоимость помещения, но если вдруг захочется 12 комнатный "холостяцкий флэт", то придется раскошелиться. В целом основная масса значений вполне ожидаема, за исключения падения стоимости жилья почти в два раза за 4 года!!!

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#
#    Тут вывод не дописан. Видимо, не сохранился при отправке
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Проведен основательный и подробный анализ. Все наглядно - графики и гистограммы подтверждают обоснованные выводы. Учти мои замечания. Возможно, придется немного подправить выводы. Жду твой проект на повторное ревью. Успехов!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Благодарю за поддержку! Надеюсь в нынешней итеррации проекта все правильно. Буду рад обратной связи на свои вопросы и возможности сохранисть все твои замечания в проекте в будущем.
#  P.S.
# Весной 2022 года проводили "медовые две недели" с женой в Петербурге. Жили на Петроградке, ни минуты покоя. До этого в течение двух месяцев составляли подробную программу на каждый день, собирая инфу по друзьям и интернету, в результате чего родилась Excel-таблица с местами и подробным таймингом посещения. Севкабельпорт, Birch, Рфкмуые

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Андрей, замечания устранены 👍. Уверен, мои советы пригодятся тебе в новых проектах. Успехов в обучении! 😉
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [ ]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [ ]  в каждом этапе есть промежуточные выводы
# - [ ]  есть общий вывод
